# %%
import pandas as pd
from pymongo import MongoClient
import pprint
import re
import numpy as np
import folium
import os
import requests
from dotenv import load_dotenv
load_dotenv()

if not "KEY" in os.environ:
    raise ValueError("You should pass a KEY")
KEY = os.environ["KEY"]

# %%
client = MongoClient('mongodb://localhost:27017/')
db = client.companies

# %%
companies = db.data_companies_clean.find({ 
    "total_money_raised":{
        "$gte": 1000000
    }
}
)  

#Primero filtro en las ganancias. Queremos empresas con al menos 1000000 de ingresos

# %%
data_companies = pd.DataFrame(companies)

# %%
data_companies[data_companies['total_money_raised']==data_companies['total_money_raised'].max()]

#Para hacer una primera aproximación veo qué empresa tiene más dinero.
# Out:
#                          _id category_code       city country  founded_year  \
# 68  5d2737547bf280155f216109        social  Vancouver     CAN          2008
#
#                                        geoDescription   latitude   longitude  \
# 68  {'type': 'Point', 'coordinates': [-123.0952381...  49.285173 -123.095238
#
#          name  number_of_employees  total_money_raised
# 68  HootSuite                370.0           190000000

# %%
list_geo = []
for e in range(len(data_companies)):
    list_geo.append(data_companies.geoDescription[e]) #Lista con todas las geoDescription

# %%
#Función para saber el número de empresas que hay alrededor de cada una de ellas.

def findNear(list_geo, radio_meters):
        geopoint = list_geo
        return list(db.data_companies_clean.find({
        "geoDescription": {
         "$near": {
             "$geometry": geopoint,
             "$maxDistance": radio_meters
         }
       }
    }
    )
    ) 

radio_meters = 5000
list_number_offices = []
list_offices=[]
for i in range(len(data_companies)):
    num_offices =  findNear(list_geo[i], radio_meters)
    list_offices.append(num_offices)
    list_number_offices.append(len(num_offices))
data_companies['number of offices near'] = list_number_offices

# %%
data_companies.head()
# Out:
#                         _id category_code       city country  founded_year  \
# 0  5d2737547bf280155f216096       finance     London     GBR          2007
# 1  5d2737547bf280155f216097          tech   Tel-Aviv     ISR          2007
# 2  5d2737547bf280155f216098          tech    Toronto     CAN          2007
# 3  5d2737547bf280155f216099          tech   Helsinki     FIN          2007
# 4  5d2737547bf280155f21609a          tech  Amsterdam     NLD          2007
#
#                                       geoDescription   latitude  longitude  \
# 0  {'type': 'Point', 'coordinates': [-0.1418973, ...  51.510880  -0.141897
# 1  {'type': 'Point', 'coordinates': [34.7595, 32....  32.055400  34.759500
# 2  {'type': 'Point', 'coordinates': [-79.388279, ...  43.666953 -79.388279
# 3  {'type': 'Point', 'coordinates': [24.9410012, ...  60.168149  24.941001
# 4  {'type': 'Point', 'coordinates': [4.8948623, 5...  52.374523   4.894862
#
#         name  number_of_employees  total_money_raised  number of offices near
# 0   Seedcamp                  4.0             5000000                      18
# 1  Flixwagon                 10.0             2500000                       5
# 2   ModiFace                 35.0             4250000                       5
# 3       XIHA                  8.0             1000000                       2
# 4    Wakoopa                  8.0             1000000                       6

# %%
data_companies['money by offices'] = data_companies['total_money_raised']/data_companies['number of offices near']

#Media de dinero por oficinas y creo nueva columna

# %%
def sumEmployees(list_offices):
    list_employee = []
    res=0
    for company in list_offices:
        lst=[]
        for i in company:
            lst.append(i['number_of_employees'])
        res+=i['number_of_employees']
        list_employee.append(lst)
    result = [sum(b) for b in list_employee]
    return result

#función para calcular la suma de empleados por oficina

# %%
data_companies['employee by offices'] = sumEmployees(list_offices)/data_companies['number of offices near']

# %%
data_companies = data_companies[data_companies['number of offices near'] > 1]

#Quiero que al menos haya una oficina cerca

# %%
data_companies['ranking'] = data_companies['number of offices near']*0.8 + (data_companies['money by offices']/1000000)*0.6 + data_companies['employee by offices']*0.4

#Establezco un pequeño ranking para darle más importancia a las empresas cerca, seguid de otros valores

# %%
data_companies = data_companies.sort_values(['ranking'], ascending=False)

#Ordeno por ranking final

# %%
BASE_URL = "https://maps.googleapis.com/maps/api/place/nearbysearch"

# %%
res = requests.get("{}/json?location=49.285173,-123.095238&radius=1500&type=school&key={}".format(BASE_URL, KEY)).json()

# %%
#Con la Api de google busco las escuelas cerca sobre la empresa localizada en Vancouver que es la primera según ranking

coordinates_schools_latitude = []
coordinates_schools_longitude = []
name_schools = []
for i in range(len(res)):
    coordinates_schools_latitude.append(res['results'][i]['geometry']['location']["lat"])
    coordinates_schools_longitude.append(res['results'][i]['geometry']['location']["lng"])
    name_schools.append(res['results'][i]['name'])
print(coordinates_schools_latitude, coordinates_schools_longitude, name_schools)
# Out:
# [49.28071019999999, 49.2724496, 49.2847903, 49.2803269] [-123.1115084, -123.0957245, -123.1136753, -123.1060349] ['Vancouver Community College', 'Eton College Canada', 'ILAC - International Language Academy of Canada', 'International House Vancouver - Modern Languages']

# %%
dicc = {'latitude_school':coordinates_schools_latitude,
       'longitude_school': coordinates_schools_longitude,
       'name_school': name_schools}

# %%
dataframe_schools = pd.DataFrame(dicc)

# %%
display(dataframe_schools)
# Out:
#    latitude_school  longitude_school  \
# 0        49.280710       -123.111508
# 1        49.272450       -123.095725
# 2        49.284790       -123.113675
# 3        49.280327       -123.106035
#
#                                         name_school
# 0                       Vancouver Community College
# 1                               Eton College Canada
# 2   ILAC - International Language Academy of Canada
# 3  International House Vancouver - Modern Languages

# %%
display(data_companies)
# Out:
#                          _id category_code                city country  \
# 0   5d2737547bf280155f216109        social           Vancouver     CAN
# 2   5d2737547bf280155f21611d          tech           Sao Paulo     BRA
# 7   5d2737547bf280155f216128          tech           Vancouver     CAN
# 29  5d2737547bf280155f2160b7          tech       Vancouver, BC     CAN
# 50  5d2737547bf280155f2160a4          tech           Vancouver     CAN
# 11  5d2737547bf280155f21609c     education              Berlin     DEU
# 15  5d2737547bf280155f216118          tech              Berlin     DEU
# 4   5d2737547bf280155f2160d3        social              Berlin     DEU
# 35  5d2737547bf280155f2160c0          tech              Berlin     DEU
# 1   5d2737547bf280155f2160d9          tech        Copenhagen V     DNK
# 3   5d2737547bf280155f2160bc          tech            Budapest     HUN
# 40  5d2737547bf280155f216122          tech              London     GBR
# 21  5d2737547bf280155f2160bb          tech              London     GBR
# 42  5d2737547bf280155f2160ec          tech              London     GBR
# 55  5d2737547bf280155f21611e         music              London     GBR
# 58  5d2737547bf280155f216127          tech              London     GBR
# 49  5d2737547bf280155f216096       finance              London     GBR
# 61  5d2737547bf280155f2160fd        social              London     GBR
# 41  5d2737547bf280155f21609d          tech              London     GBR
# 53  5d2737547bf280155f2160a6          tech              London     GBR
# 30  5d2737547bf280155f2160d6   real_estate              London     GBR
# 56  5d2737547bf280155f2160d5        social              London     GBR
# 28  5d2737547bf280155f2160f8          tech              London     GBR
# 51  5d2737547bf280155f2160ba          tech              London     GBR
# 62  5d2737547bf280155f21611c    enterprise              London     GBR
# 52  5d2737547bf280155f2160ab        sports              London     GBR
# 33  5d2737547bf280155f2160e0          tech              London     GBR
# 6   5d2737547bf280155f2160aa        social        Buenos Aires     ARG
# 14  5d2737547bf280155f2160d8          tech              London     GBR
# 18  5d2737547bf280155f2160a5          news               Paris     FRA
# ..                       ...           ...                 ...     ...
# 59  5d2737547bf280155f2160e2          tech               PARIS     FRA
# 48  5d2737547bf280155f216112          tech               Paris     FRA
# 44  5d2737547bf280155f2160f4          tech             Halifax     CAN
# 54  5d2737547bf280155f21610f          news                         FRA
# 8   5d2737547bf280155f2160ac    enterprise             Toronto     CAN
# 23  5d2737547bf280155f216098          tech             Toronto     CAN
# 12  5d2737547bf280155f2160a8          tech            Tel Aviv     ISR
# 5   5d2737547bf280155f2160bf          tech              Munich     DEU
# 31  5d2737547bf280155f2160c9          tech           Ramat Gan     ISR
# 32  5d2737547bf280155f2160cd          tech           Ramat Gan     ISR
# 36  5d2737547bf280155f216097          tech            Tel-Aviv     ISR
# 27  5d2737547bf280155f2160b8          tech              Munich     DEU
# 17  5d2737547bf280155f2160d0          tech          Gothenburg     SWE
# 16  5d2737547bf280155f2160c8          tech          Gothenburg     SWE
# 13  5d2737547bf280155f2160e6        social              Madrid     ESP
# 24  5d2737547bf280155f2160b6          tech           Stockholm     SWE
# 20  5d2737547bf280155f21609e          tech              Madrid     ESP
# 19  5d2737547bf280155f216124          tech           Barcelona     ESP
# 26  5d2737547bf280155f2160ce    enterprise           Barcelona     ESP
# 25  5d2737547bf280155f2160ca    enterprise           Barcelona     ESP
# 9   5d2737547bf280155f21611a          tech           Amsterdam     NLD
# 34  5d2737547bf280155f216108          tech               Paris     FRA
# 47  5d2737547bf280155f2160b9     education           Amsterdam     NLD
# 57  5d2737547bf280155f21609a          tech           Amsterdam     NLD
# 43  5d2737547bf280155f2160b1          tech  Asnieres sur seine     FRA
# 10  5d2737547bf280155f2160d2         music            Brussels     BEL
# 45  5d2737547bf280155f216126          tech            Brussels     BEL
# 37  5d2737547bf280155f216099          tech            Helsinki     FIN
# 39  5d2737547bf280155f2160c4        travel           Singapore     SGP
# 38  5d2737547bf280155f2160cb        travel           Singapore     SGP
#
#     founded_year                                     geoDescription  \
# 0           2008  {'type': 'Point', 'coordinates': [-123.0952381...
# 2           2009  {'type': 'Point', 'coordinates': [-46.6388182,...
# 7           2009  {'type': 'Point', 'coordinates': [-123.109217,...
# 29          2007  {'type': 'Point', 'coordinates': [-123.120893,...
# 50          2007  {'type': 'Point', 'coordinates': [-123.1078045...
# 11          2007  {'type': 'Point', 'coordinates': [13.38861, 52...
# 15          2007  {'type': 'Point', 'coordinates': [13.398504, 5...
# 4           2008  {'type': 'Point', 'coordinates': [13.3842605, ...
# 35          2008  {'type': 'Point', 'coordinates': [13.4124563, ...
# 1           2007  {'type': 'Point', 'coordinates': [12.5605372, ...
# 3           2009  {'type': 'Point', 'coordinates': [19.059078, 4...
# 40          2008  {'type': 'Point', 'coordinates': [-0.1366861, ...
# 21          2007  {'type': 'Point', 'coordinates': [-0.1020894, ...
# 42          2009  {'type': 'Point', 'coordinates': [-0.1020265, ...
# 55          2008  {'type': 'Point', 'coordinates': [-0.0856982, ...
# 58          2008  {'type': 'Point', 'coordinates': [-0.1037742, ...
# 49          2007  {'type': 'Point', 'coordinates': [-0.1418973, ...
# 61          2008  {'type': 'Point', 'coordinates': [-0.1046546, ...
# 41          2007  {'type': 'Point', 'coordinates': [-0.0934254, ...
# 53          2007  {'type': 'Point', 'coordinates': [-0.0766034, ...
# 30          2007  {'type': 'Point', 'coordinates': [-0.1010801, ...
# 56          2007  {'type': 'Point', 'coordinates': [-0.0925694, ...
# 28          2009  {'type': 'Point', 'coordinates': [-0.0936688, ...
# 51          2008  {'type': 'Point', 'coordinates': [-0.1262362, ...
# 62          2008  {'type': 'Point', 'coordinates': [-0.1262362, ...
# 52          2008  {'type': 'Point', 'coordinates': [-0.130772, 5...
# 33          2007  {'type': 'Point', 'coordinates': [-0.1506897, ...
# 6           2007  {'type': 'Point', 'coordinates': [-58.417309, ...
# 14          2008  {'type': 'Point', 'coordinates': [-0.1815999, ...
# 18          2008  {'type': 'Point', 'coordinates': [2.350987, 48...
# ..           ...                                                ...
# 59          2007  {'type': 'Point', 'coordinates': [2.3216223, 4...
# 48          2008  {'type': 'Point', 'coordinates': [2.3389864, 4...
# 44          2007  {'type': 'Point', 'coordinates': [-79.3777473,...
# 54          2007  {'type': 'Point', 'coordinates': [2.3935987, 4...
# 8           2008  {'type': 'Point', 'coordinates': [-79.406775, ...
# 23          2007  {'type': 'Point', 'coordinates': [-79.388279, ...
# 12          2008  {'type': 'Point', 'coordinates': [34.7595, 32....
# 5           2007  {'type': 'Point', 'coordinates': [11.5893956, ...
# 31          2008  {'type': 'Point', 'coordinates': [34.8003705, ...
# 32          2008  {'type': 'Point', 'coordinates': [34.8003705, ...
# 36          2007  {'type': 'Point', 'coordinates': [34.7595, 32....
# 27          2007  {'type': 'Point', 'coordinates': [11.5677288, ...
# 17          2009  {'type': 'Point', 'coordinates': [18.036587, 5...
# 16          2009  {'type': 'Point', 'coordinates': [18.036587, 5...
# 13          2008  {'type': 'Point', 'coordinates': [-3.6830316, ...
# 24          2007  {'type': 'Point', 'coordinates': [18.064488, 5...
# 20          2007  {'type': 'Point', 'coordinates': [-3.6952896, ...
# 19          2009  {'type': 'Point', 'coordinates': [2.1920231, 4...
# 26          2007  {'type': 'Point', 'coordinates': [2.192023, 41...
# 25          2007  {'type': 'Point', 'coordinates': [2.192023, 41...
# 9           2009  {'type': 'Point', 'coordinates': [4.8928722, 5...
# 34          2008  {'type': 'Point', 'coordinates': [2.4476331, 4...
# 47          2007  {'type': 'Point', 'coordinates': [4.912106, 52...
# 57          2007  {'type': 'Point', 'coordinates': [4.8948623, 5...
# 43          2007  {'type': 'Point', 'coordinates': [2.2860418, 4...
# 10          2007  {'type': 'Point', 'coordinates': [4.33511, 50....
# 45          2009  {'type': 'Point', 'coordinates': [4.3464721, 5...
# 37          2007  {'type': 'Point', 'coordinates': [24.9410012, ...
# 39          2011  {'type': 'Point', 'coordinates': [-157.78907, ...
# 38          2011  {'type': 'Point', 'coordinates': [-157.78907, ...
#
#      latitude   longitude             name  number_of_employees  \
# 0   49.285173 -123.095238        HootSuite                370.0
# 2  -23.548943  -46.638818       Brandsclub                140.0
# 7   49.282455 -123.109217       Tiny Speck                 45.0
# 17            24.000000  12.700000
# 16            24.000000  12.700000
# 13            23.333333  12.673333
# 24            24.000000  12.500000
# 20            23.333333  12.283333
# 19            14.500000  11.275000
# 26            14.500000  11.100000
# 25            14.500000  11.100000
# 9             12.000000  10.940000
# 34            20.000000   9.930000
# 47            12.000000   9.810000
# 57            12.000000   9.700000
# 43            15.000000   8.650000
# 10            10.000000   7.600000
# 45            10.000000   6.626000
# 37             7.000000   4.700000
# 39             4.000000   3.500000
# 38             4.000000   3.500000
#
# [63 rows x 15 columns]

# %%
data_companies = data_companies.reset_index(drop=True)

# %%
data_companies.to_csv('./data_companies_select.csv')

# %%
res = requests.get("{}/json?location=49.285173,-123.095238&radius=1500&type=cafe&key={}&name=Starbucks".format(BASE_URL, KEY))

# %%
res = res.json()

# %%
coordinates_starbucks_latitude = []
coordinates_starbucks_longitude = []
for i in range(len(res)):
    coordinates_starbucks_latitude.append(res['results'][i]['geometry']['location']["lat"])
    coordinates_starbucks_longitude.append(res['results'][i]['geometry']['location']["lng"])
print(coordinates_starbucks_latitude, coordinates_starbucks_longitude)
# Out:
# [49.2856442, 49.2859207, 49.2844427] [-123.111855, -123.1151827, -123.108513]

# %%
dicc_starbucks = {'latitude_starbucks':coordinates_starbucks_latitude,
       'longitude_starbucks': coordinates_starbucks_longitude}
dataframe_starbucks = pd.DataFrame(dicc_starbucks)
display(dataframe_starbucks)
# Out:
#    latitude_starbucks  longitude_starbucks
# 0           49.285644          -123.111855
# 1           49.285921          -123.115183
# 2           49.284443          -123.108513

# %%
#Mapa con toda las compañías

# %%
map_companies = folium.Map(location=[51.510880, -0.141897], width=750, height=500, zoom_start=2)
for index, row in data_companies.iterrows():
    folium.CircleMarker([row['latitude'], row['longitude']],
                        radius=3,
                        popup="Name company: {}. Money: {}".format(row['name'], row['total_money_raised']),
                        fill_color="#F35C50", # divvy color
                       ).add_to(map_companies)

map_companies.save('map_companies.html')
map_companies
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#Mapa con las empresas del radio en la zona, escuelas cercanas (en rojo), Starbucks (verde) y la calle donde 
#sería interesante localizar la empresa

# %%
map_vancouver = folium.Map(location=[49.285173, -123.095238], width=750, height=500, zoom_start=15)
for index, row in data_companies.iterrows():
    folium.Marker([row['latitude'], row['longitude']],
                        radius=7,
                        popup="Name company: {}. Money: {}. Employees{}".format(row['name'], row['total_money_raised'], row['number_of_employees']),
                        icon=folium.Icon(color='red', icon='info-sign'),
                        fill_color="#F45649", 
                       ).add_to(map_vancouver)
for index, row in dataframe_schools.iterrows():
    folium.Marker([row['latitude_school'], row['longitude_school']],
                        radius=4,
                        popup="School: {}".format(row['name_school']),
                        icon=folium.Icon(icon='cloud'),
                        fill_color="#F35C50", # divvy color
                       ).add_to(map_vancouver)
for index, row in dataframe_starbucks.iterrows():
    folium.Marker([row['latitude_starbucks'], row['longitude_starbucks']],
                        radius=4,
                        icon=folium.Icon(color='darkgreen',icon='info-sign'),
                        fill_color="#F35C50", # divvy color
                       ).add_to(map_vancouver)
folium.Marker([49.282223,-123.109113],
                        radius=4,
                        icon=folium.Icon(color='pink',icon='info-sign'),
                        popup="Our company",
                        fill_color="#F35C50", # divvy color
                       ).add_to(map_vancouver)
map_vancouver.save('map_vancouver.html')
map_vancouver
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
