# %%
import pandas as pd
from pymongo import MongoClient
import pprint
import re
import numpy as np
import folium
import os
import requests
from dotenv import load_dotenv
load_dotenv()

if not "KEY" in os.environ:
    raise ValueError("You should pass a KEY")
KEY = os.environ["KEY"]

# %%
client = MongoClient('mongodb://localhost:27017/')
db = client.companies

# %%
companies = db.data_companies_clean.find({ 
    "total_money_raised":{
        "$gte": 1000000
    }
}
)  

#Primero filtro en las ganancias. Queremos empresas con al menos 1000000 de ingresos

# %%
data_companies = pd.DataFrame(companies)

# %%
data_companies[data_companies['total_money_raised']==data_companies['total_money_raised'].max()]

#Para hacer una primera aproximación veo qué empresa tiene más dinero.
# Out:
#                          _id category_code       city country  founded_year  \
# 68  5d2737547bf280155f216109        social  Vancouver     CAN          2008
#
#                                        geoDescription   latitude   longitude  \
# 68  {'type': 'Point', 'coordinates': [-123.0952381...  49.285173 -123.095238
#
#          name  number_of_employees  total_money_raised
# 68  HootSuite                370.0           190000000

# %%
list_geo = []
for e in range(len(data_companies)):
    list_geo.append(data_companies.geoDescription[e]) #Lista con todas las geoDescription

# %%
#Función para saber el número de empresas que hay alrededor de cada una de ellas.

def findNear(list_geo, radio_meters):
        geopoint = list_geo
        return list(db.data_companies_clean.find({
        "geoDescription": {
         "$near": {
             "$geometry": geopoint,
             "$maxDistance": radio_meters
         }
       }
    }
    )
    ) 

radio_meters = 5000
list_number_offices = []
list_offices=[]
for i in range(len(data_companies)):
    num_offices =  findNear(list_geo[i], radio_meters)
    list_offices.append(num_offices)
    list_number_offices.append(len(num_offices))
data_companies['number of offices near'] = list_number_offices

# %%
data_companies.head()
# Out:
#                         _id category_code       city country  founded_year  \
# 0  5d2737547bf280155f216096       finance     London     GBR          2007
# 1  5d2737547bf280155f216097          tech   Tel-Aviv     ISR          2007
# 2  5d2737547bf280155f216098          tech    Toronto     CAN          2007
# 3  5d2737547bf280155f216099          tech   Helsinki     FIN          2007
# 4  5d2737547bf280155f21609a          tech  Amsterdam     NLD          2007
#
#                                       geoDescription   latitude  longitude  \
# 0  {'type': 'Point', 'coordinates': [-0.1418973, ...  51.510880  -0.141897
# 1  {'type': 'Point', 'coordinates': [34.7595, 32....  32.055400  34.759500
# 2  {'type': 'Point', 'coordinates': [-79.388279, ...  43.666953 -79.388279
# 3  {'type': 'Point', 'coordinates': [24.9410012, ...  60.168149  24.941001
# 4  {'type': 'Point', 'coordinates': [4.8948623, 5...  52.374523   4.894862
#
#         name  number_of_employees  total_money_raised  number of offices near
# 0   Seedcamp                  4.0             5000000                      18
# 1  Flixwagon                 10.0             2500000                       5
# 2   ModiFace                 35.0             4250000                       5
# 3       XIHA                  8.0             1000000                       2
# 4    Wakoopa                  8.0             1000000                       6

# %%
data_companies['money by offices'] = data_companies['total_money_raised']/data_companies['number of offices near']

#Media de dinero por oficinas y creo nueva columna

# %%
def sumEmployees(list_offices):
    list_employee = []
    res=0
    for company in list_offices:
        lst=[]
        for i in company:
            lst.append(i['number_of_employees'])
        res+=i['number_of_employees']
        list_employee.append(lst)
    result = [sum(b) for b in list_employee]
    return result

#función para calcular la suma de empleados por oficina

# %%
data_companies['employee by offices'] = sumEmployees(list_offices)/data_companies['number of offices near']

# %%
data_companies = data_companies[data_companies['number of offices near'] > 1]

#Quiero que al menos haya una oficina cerca

# %%
#Unifico los valores para poder hacer el ranking 

data_companies['Rank_employee'] = data_companies['employee by offices'].rank()
data_companies['Rank_money'] = data_companies['money by offices'].rank()
data_companies['Rank_offices'] = data_companies['number of offices near'].rank()

data_companies.head()
# Out:
#                         _id category_code       city country  founded_year  \
# 0  5d2737547bf280155f216096       finance     London     GBR          2007
# 1  5d2737547bf280155f216097          tech   Tel-Aviv     ISR          2007
# 2  5d2737547bf280155f216098          tech    Toronto     CAN          2007
# 3  5d2737547bf280155f216099          tech   Helsinki     FIN          2007
# 4  5d2737547bf280155f21609a          tech  Amsterdam     NLD          2007
#
#                                       geoDescription   latitude  longitude  \
# 0  {'type': 'Point', 'coordinates': [-0.1418973, ...  51.510880  -0.141897
# 1  {'type': 'Point', 'coordinates': [34.7595, 32....  32.055400  34.759500
# 2  {'type': 'Point', 'coordinates': [-79.388279, ...  43.666953 -79.388279
# 3  {'type': 'Point', 'coordinates': [24.9410012, ...  60.168149  24.941001
# 4  {'type': 'Point', 'coordinates': [4.8948623, 5...  52.374523   4.894862
#
#         name  number_of_employees  total_money_raised  number of offices near  \
# 0   Seedcamp                  4.0             5000000                      18
# 1  Flixwagon                 10.0             2500000                       5
# 2   ModiFace                 35.0             4250000                       5
# 3       XIHA                  8.0             1000000                       2
# 4    Wakoopa                  8.0             1000000                       6
#
#    money by offices  employee by offices  Rank_employee  Rank_money  \
# 0     277777.777778            24.888889           35.0        14.0
# 1     500000.000000            23.800000           20.5        25.5
# 2     850000.000000            28.000000           45.5        40.0
# 3     500000.000000             7.000000            3.0        25.5
# 4     166666.666667            12.000000            7.0         6.0
#
#    Rank_offices
# 0          59.5
# 1          23.5
# 2          23.5
# 3           5.5
# 4          32.5

# %%
data_companies['ranking_total'] =  data_companies['Rank_money']*0.8 + data_companies['Rank_employee']*0.6 + data_companies['Rank_offices']*0.4

#Hago un ranking total

# %%
data_companies = data_companies.sort_values(['ranking_total'], ascending=False)

#Ordeno por ranking total

# %%
BASE_URL = "https://maps.googleapis.com/maps/api/place/nearbysearch"

# %%
res = requests.get("{}/json?location=49.285173,-123.095238&radius=1500&type=school&key={}".format(BASE_URL, KEY)).json()

# %%
#Con la Api de google busco las escuelas cerca sobre la empresa localizada en Vancouver que es la primera según ranking

coordinates_schools_latitude = []
coordinates_schools_longitude = []
name_schools = []
for i in range(len(res)):
    coordinates_schools_latitude.append(res['results'][i]['geometry']['location']["lat"])
    coordinates_schools_longitude.append(res['results'][i]['geometry']['location']["lng"])
    name_schools.append(res['results'][i]['name'])
print(coordinates_schools_latitude, coordinates_schools_longitude, name_schools)
# Out:
# [49.28071019999999, 49.2724496, 49.2847903, 49.2803269] [-123.1115084, -123.0957245, -123.1136753, -123.1060349] ['Vancouver Community College', 'Eton College Canada', 'ILAC - International Language Academy of Canada', 'International House Vancouver - Modern Languages']

# %%
dicc = {'latitude_school':coordinates_schools_latitude,
       'longitude_school': coordinates_schools_longitude,
       'name_school': name_schools}

# %%
dataframe_schools = pd.DataFrame(dicc)

# %%
display(dataframe_schools)
# Out:
#    latitude_school  longitude_school  \
# 0        49.280710       -123.111508
# 1        49.272450       -123.095725
# 2        49.284790       -123.113675
# 3        49.280327       -123.106035
#
#                                         name_school
# 0                       Vancouver Community College
# 1                               Eton College Canada
# 2   ILAC - International Language Academy of Canada
# 3  International House Vancouver - Modern Languages

# %%
display(data_companies)
# Out:
#                          _id category_code                city country  \
# 68  5d2737547bf280155f216109        social           Vancouver     CAN
# 39  5d2737547bf280155f2160d3        social              Berlin     DEU
# 85  5d2737547bf280155f216128          tech           Vancouver     CAN
# 5   5d2737547bf280155f21609c     education              Berlin     DEU
# 77  5d2737547bf280155f21611d          tech           Sao Paulo     BRA
# 74  5d2737547bf280155f216118          tech              Berlin     DEU
# 44  5d2737547bf280155f2160d9          tech        Copenhagen V     DNK
# 25  5d2737547bf280155f2160bc          tech            Budapest     HUN
# 15  5d2737547bf280155f2160ac    enterprise             Toronto     CAN
# 24  5d2737547bf280155f2160bb          tech              London     GBR
# 13  5d2737547bf280155f2160aa        social        Buenos Aires     ARG
# 43  5d2737547bf280155f2160d8          tech              London     GBR
# 20  5d2737547bf280155f2160b7          tech       Vancouver, BC     CAN
# 27  5d2737547bf280155f2160bf          tech              Munich     DEU
# 9   5d2737547bf280155f2160a5          news               Paris     FRA
# 47  5d2737547bf280155f2160e0          tech              London     GBR
# 28  5d2737547bf280155f2160c0          tech              Berlin     DEU
# 65  5d2737547bf280155f216101          tech               Paris     FRA
# 79  5d2737547bf280155f216122          tech              London     GBR
# 2   5d2737547bf280155f216098          tech             Toronto     CAN
# 61  5d2737547bf280155f2160f8          tech              London     GBR
# 54  5d2737547bf280155f2160ec          tech              London     GBR
# 11  5d2737547bf280155f2160a8          tech            Tel Aviv     ISR
# 75  5d2737547bf280155f21611a          tech           Amsterdam     NLD
# 8   5d2737547bf280155f2160a4          tech           Vancouver     CAN
# 37  5d2737547bf280155f2160d0          tech          Gothenburg     SWE
# 31  5d2737547bf280155f2160c8          tech          Gothenburg     SWE
# 21  5d2737547bf280155f2160b8          tech              Munich     DEU
# 71  5d2737547bf280155f216112          tech               Paris     FRA
# 14  5d2737547bf280155f2160ab        sports              London     GBR
# ..                       ...           ...                 ...     ...
# 81  5d2737547bf280155f216124          tech           Barcelona     ESP
# 6   5d2737547bf280155f21609d          tech              London     GBR
# 78  5d2737547bf280155f21611e         music              London     GBR
# 59  5d2737547bf280155f2160f4          tech             Halifax     CAN
# 19  5d2737547bf280155f2160b6          tech           Stockholm     SWE
# 46  5d2737547bf280155f2160de          tech    Levallois-Perret     FRA
# 38  5d2737547bf280155f2160d2         music            Brussels     BEL
# 84  5d2737547bf280155f216127          tech              London     GBR
# 7   5d2737547bf280155f21609e          tech              Madrid     ESP
# 36  5d2737547bf280155f2160ce    enterprise           Barcelona     ESP
# 33  5d2737547bf280155f2160ca    enterprise           Barcelona     ESP
# 64  5d2737547bf280155f2160fd        social              London     GBR
# 32  5d2737547bf280155f2160c9          tech           Ramat Gan     ISR
# 35  5d2737547bf280155f2160cd          tech           Ramat Gan     ISR
# 23  5d2737547bf280155f2160ba          tech              London     GBR
# 48  5d2737547bf280155f2160e2          tech               PARIS     FRA
# 10  5d2737547bf280155f2160a6          tech              London     GBR
# 1   5d2737547bf280155f216097          tech            Tel-Aviv     ISR
# 73  5d2737547bf280155f216117          tech               Paris     FRA
# 76  5d2737547bf280155f21611c    enterprise              London     GBR
# 41  5d2737547bf280155f2160d5        social              London     GBR
# 69  5d2737547bf280155f21610f          news                         FRA
# 67  5d2737547bf280155f216108          tech               Paris     FRA
# 22  5d2737547bf280155f2160b9     education           Amsterdam     NLD
# 17  5d2737547bf280155f2160b1          tech  Asnieres sur seine     FRA
# 3   5d2737547bf280155f216099          tech            Helsinki     FIN
# 29  5d2737547bf280155f2160c4        travel           Singapore     SGP
# 34  5d2737547bf280155f2160cb        travel           Singapore     SGP
# 83  5d2737547bf280155f216126          tech            Brussels     BEL
# 4   5d2737547bf280155f21609a          tech           Amsterdam     NLD
#
#     founded_year                                     geoDescription  \
# 68          2008  {'type': 'Point', 'coordinates': [-123.0952381...
# 39          2008  {'type': 'Point', 'coordinates': [13.3842605, ...
# 85          2009  {'type': 'Point', 'coordinates': [-123.109217,...
# 5           2007  {'type': 'Point', 'coordinates': [13.38861, 52...
# 77          2009  {'type': 'Point', 'coordinates': [-46.6388182,...
# 74          2007  {'type': 'Point', 'coordinates': [13.398504, 5...
# 44          2007  {'type': 'Point', 'coordinates': [12.5605372, ...
# 25          2009  {'type': 'Point', 'coordinates': [19.059078, 4...
# 15          2008  {'type': 'Point', 'coordinates': [-79.406775, ...
# 24          2007  {'type': 'Point', 'coordinates': [-0.1020894, ...
# 13          2007  {'type': 'Point', 'coordinates': [-58.417309, ...
# 43          2008  {'type': 'Point', 'coordinates': [-0.1815999, ...
# 20          2007  {'type': 'Point', 'coordinates': [-123.120893,...
# 27          2007  {'type': 'Point', 'coordinates': [11.5893956, ...
# 9           2008  {'type': 'Point', 'coordinates': [2.350987, 48...
# 47          2007  {'type': 'Point', 'coordinates': [-0.1506897, ...
# 28          2008  {'type': 'Point', 'coordinates': [13.4124563, ...
# 65          2008  {'type': 'Point', 'coordinates': [2.3347594, 4...
# 79          2008  {'type': 'Point', 'coordinates': [-0.1366861, ...
# 2           2007  {'type': 'Point', 'coordinates': [-79.388279, ...
# 61          2009  {'type': 'Point', 'coordinates': [-0.0936688, ...
# 54          2009  {'type': 'Point', 'coordinates': [-0.1020265, ...
# 11          2008  {'type': 'Point', 'coordinates': [34.7595, 32....
# 75          2009  {'type': 'Point', 'coordinates': [4.8928722, 5...
# 8           2007  {'type': 'Point', 'coordinates': [-123.1078045...
# 37          2009  {'type': 'Point', 'coordinates': [18.036587, 5...
# 31          2009  {'type': 'Point', 'coordinates': [18.036587, 5...
# 21          2007  {'type': 'Point', 'coordinates': [11.5677288, ...
# 71          2008  {'type': 'Point', 'coordinates': [2.3389864, 4...
# 14          2008  {'type': 'Point', 'coordinates': [-0.130772, 5...
# ..           ...                                                ...
# 81          2009  {'type': 'Point', 'coordinates': [2.1920231, 4...
# 6           2007  {'type': 'Point', 'coordinates': [-0.0934254, ...
# 78          2008  {'type': 'Point', 'coordinates': [-0.0856982, ...
# 59          2007  {'type': 'Point', 'coordinates': [-79.3777473,...
# 19          2007  {'type': 'Point', 'coordinates': [18.064488, 5...
# 46          2007  {'type': 'Point', 'coordinates': [2.3593849, 4...
# 38          2007  {'type': 'Point', 'coordinates': [4.33511, 50....
# 84          2008  {'type': 'Point', 'coordinates': [-0.1037742, ...
# 7           2007  {'type': 'Point', 'coordinates': [-3.6952896, ...
# 36          2007  {'type': 'Point', 'coordinates': [2.192023, 41...
# 33          2007  {'type': 'Point', 'coordinates': [2.192023, 41...
# 64          2008  {'type': 'Point', 'coordinates': [-0.1046546, ...
# 32          2008  {'type': 'Point', 'coordinates': [34.8003705, ...
# 35          2008  {'type': 'Point', 'coordinates': [34.8003705, ...
# 23          2008  {'type': 'Point', 'coordinates': [-0.1262362, ...
# 48          2007  {'type': 'Point', 'coordinates': [2.3216223, 4...
# 10          2007  {'type': 'Point', 'coordinates': [-0.0766034, ...
# 1           2007  {'type': 'Point', 'coordinates': [34.7595, 32....
# 73          2009  {'type': 'Point', 'coordinates': [2.3509871, 4...
# 76          2008  {'type': 'Point', 'coordinates': [-0.1262362, ...
# 41          2007  {'type': 'Point', 'coordinates': [-0.0925694, ...
# 69          2007  {'type': 'Point', 'coordinates': [2.3935987, 4...
# 67          2008  {'type': 'Point', 'coordinates': [2.4476331, 4...
# 22          2007  {'type': 'Point', 'coordinates': [4.912106, 52...
# 17          2007  {'type': 'Point', 'coordinates': [2.2860418, 4...
# 3           2007  {'type': 'Point', 'coordinates': [24.9410012, ...
# 29          2011  {'type': 'Point', 'coordinates': [-157.78907, ...
# 34          2011  {'type': 'Point', 'coordinates': [-157.78907, ...
# 83          2009  {'type': 'Point', 'coordinates': [4.3464721, 5...
# 4           2007  {'type': 'Point', 'coordinates': [4.8948623, 5...
#
#      latitude   longitude             name  number_of_employees  \
# 68  49.285173 -123.095238        HootSuite                370.0
# 39  52.530852   13.384260     ResearchGate                 74.0
# 85  49.282455 -123.109217       Tiny Speck                 45.0
# 5   52.489700   13.388610           babbel                205.0
# 77 -23.548943  -46.638818       Brandsclub                140.0
# 74  52.494727   13.398504       Moviepilot                 43.0
# 44  55.673962   12.560537       Trustpilot                100.0
# 25  47.490346   19.059078            Prezi                110.0
# 15  43.643080  -79.406775     ScribbleLive                 45.0
# 24  51.521248   -0.102089       Videoplaza                 70.0
# 13 -34.611781  -58.417309           Sonico                 84.0
# 43  51.549971   -0.181600          Movirtu                 50.0
# 20  49.275332 -123.120893            Lat49                 24.0
# 27  48.165421   11.589396          AdScale                 40.0
# 9   48.856667    2.350987        fotopedia                 17.0
# 47  51.544167   -0.150690            Adjug                 47.0
# 28  52.528361   13.412456           plista                100.0
# 65  48.868224    2.334759         ividence                 30.0
# 79  51.515202   -0.136686            Struq                 50.0
# 2   43.666953  -79.388279         ModiFace                 35.0
# 61  51.511942   -0.093669  Cognitive Match                 40.0
# 54  51.519613   -0.102027            Shutl                 10.0
# 11  32.055400   34.759500            Jinni                 35.0
# 75  52.365758    4.892872            Layar                 32.0
# 8   49.282108 -123.107805          Strutta                 12.0
# 37  59.337864   18.036587             Burt                 30.0
# 31  59.337864   18.036587             Burt                 30.0
# 21  48.128121   11.567729            Aloqa                 14.0
# 71  48.831850    2.338986            Kwaga                 10.0
# 14  51.550757   -0.130772         Smarkets                 15.0
# ..        ...         ...              ...                  ...
# 81  41.406335    2.192023          Teambox                 35.0
# 6   51.514157   -0.093425          Zemanta                 30.0
# 78  51.525377   -0.085698      Musicmetric                 15.0
# 59  43.648786  -79.377747      Mashup Arts                  6.0
# 19  59.332788   18.064488         Bambuser                 12.0
# 46  48.868722    2.359385       PrestaShop                 80.0
# 38  50.831147    4.335110        Radionomy                 12.0
# 84  51.517356   -0.103774        Testplant                 50.0
# 7   40.430940   -3.695290        eRepublik                 30.0
# 36  41.406335    2.192023           3scale                 15.0
# 33  41.406335    2.192023           3scale                 15.0
# 64  51.522427   -0.104655         Mendeley                 27.0
# 32  32.037363   34.800370          Tweegee                 22.0
# 35  32.037363   34.800370          Tweegee                 22.0
# 23  51.500152   -0.126236        TweetDeck                  5.0
# 48  48.854574    2.321622         EcoVadis                 50.0
# 10  51.522007   -0.076603         Bragster                 10.0
# 1   32.055400   34.759500        Flixwagon                 10.0
# 73  48.856667    2.350987            Ykone                 10.0
# 76  51.500152   -0.126236          oneDrum                  5.0
# 41  51.502767   -0.092569         SocialGO                 12.0
# 69  48.871109    2.393599            Rue89                 20.0
# 67  48.895271    2.447633        WEEZEVENT                 20.0
# 22  52.354525    4.912106           Myngle                 17.0
# 17  48.906480    2.286042      SquareClock                 10.0
# 3   60.168149   24.941001             XIHA                  8.0
# 29  21.303049 -157.789070        travelmob                  4.0
# 34  21.303049 -157.789070        travelmob                  4.0
# 83  50.839970    4.346472           Getyoo                 10.0
# 4   52.374523    4.894862          Wakoopa                  8.0
#
#     total_money_raised  number of offices near  money by offices  \
# 68           190000000                       6      3.166667e+07
# 39            35000000                       7      5.000000e+06
# 85            17200000                       6      2.866667e+06
# 5             10000000                       6      1.666667e+06
# 77            17000000                       2      8.500000e+06
# 74             7000000                       6      1.166667e+06
# 44            18400000                       2      9.200000e+06
# 25            14300000                       2      7.150000e+06
# 15            12000000                       5      2.400000e+06
# 24            15900000                      18      8.833333e+05
# 13             6000000                       2      3.000000e+06
# 43             5500000                       4      1.375000e+06
# 20             3800000                       6      6.333333e+05
# 27             6150000                       2      3.075000e+06
# 9             12700000                      11      1.154545e+06
# 47             6500000                      11      5.909091e+05
# 28             3800000                       7      5.428571e+05
# 65             9700000                      11      8.818182e+05
# 79             8500000                      19      4.473684e+05
# 2              4250000                       5      8.500000e+05
# 61            10200000                      16      6.375000e+05
# 54             7660000                      18      4.255556e+05
# 11             8100000                       5      1.620000e+06
# 75            13400000                       6      2.233333e+06
# 8              1600000                       6      2.666667e+05
# 37             3500000                       3      1.166667e+06
# 31             3500000                       3      1.166667e+06
# 21             1500000                       2      7.500000e+05
# 71             2150000                       7      3.071429e+05
# 14             2710000                      13      2.084615e+05
# ..                 ...                     ...               ...
# 81             6750000                       6      1.125000e+06
# 6              7350000                      17      4.323529e+05
# 78             3400000                      18      1.888889e+05
# 59             1580000                       4      3.950000e+05
# 19             2500000                       3      8.333333e+05
# 46             3900000                      11      3.545455e+05
# 38             6000000                       3      2.000000e+06
# 84             2560000                      18      1.422222e+05
# 7              2750000                       3      9.166667e+05
# 36             5000000                       6      8.333333e+05
# 33             5000000                       6      8.333333e+05
# 64             2130000                      18      1.183333e+05
# 32             3000000                       5      6.000000e+05
# 35             3000000                       5      6.000000e+05
# 23             3800000                      16      2.375000e+05
# 48             1400000                      10      1.400000e+05
# 10             3500000                      17      2.058824e+05
# 1              2500000                       5      5.000000e+05
# 73             1500000                      11      1.363636e+05
# 76             1000000                      16      6.250000e+04
# 41             3000000                      17      1.764706e+05
# 69             1840000                       9      2.044444e+05
# 67             1100000                       2      5.500000e+05
# 22             2100000                       6      3.500000e+05
# 17             1250000                       3      4.166667e+05
# 3              1000000                       2      5.000000e+05
# 29             1000000                       2      5.000000e+05
# 34             1000000                       2      5.000000e+05
# 83             1130000                       3      3.766667e+05
# 4              1000000                       6      1.666667e+05
#
#     employee by offices  Rank_employee  Rank_money  Rank_offices  \
# 68            78.500000           60.5        63.0          32.5
# 39            62.857143           55.5        59.0          40.0
# 85            78.500000           60.5        56.0          32.5
# 5             72.500000           57.5        52.0          32.5
# 77            95.000000           63.0        61.0           5.5
# 74            72.500000           57.5        47.0          32.5
# 44            54.000000           53.0        62.0           5.5
# 25            56.000000           54.0        60.0           5.5
# 15            28.000000           45.5        55.0          23.5
# 24            25.111111           38.0        42.0          59.5
# 13            44.000000           52.0        57.0           5.5
# 43            40.500000           51.0        49.0          19.5
# 20            78.500000           60.5        34.0          32.5
# 27            27.000000           43.5        58.0           5.5
# 9             24.727273           32.5        45.0          46.0
# 47            31.090909           49.0        30.0          46.0
# 28            62.857143           55.5        28.0          40.0
# 65            24.727273           32.5        41.0          46.0
# 79            26.210526           42.0        23.0          63.0
# 2             28.000000           45.5        40.0          23.5
# 61            24.375000           30.0        35.0          51.0
# 54            25.111111           38.0        21.0          59.5
# 11            23.800000           20.5        51.0          23.5
# 75            12.000000            7.0        54.0          32.5
# 8             78.500000           60.5        13.0          32.5
# 37            24.000000           26.0        47.0          14.5
# 31            24.000000           26.0        47.0          14.5
# 21            27.000000           43.5        36.0           5.5
# 71            30.571429           48.0        15.0          40.0
# 14            29.384615           47.0        11.0          49.0
# ..                  ...            ...         ...           ...
# 81            14.500000           10.0        44.0          32.5
# 6             23.823529           23.5        22.0          54.5
# 78            25.111111           38.0         8.0          59.5
# 59            34.000000           50.0        19.0          19.5
# 19            24.000000           26.0        38.0          14.5
# 46            24.727273           32.5        17.0          46.0
# 38            10.000000            4.5        53.0          14.5
# 84            25.111111           38.0         5.0          59.5
# 7             23.333333           16.5        43.0          14.5
# 36            14.500000           10.0        38.0          32.5
# 33            14.500000           10.0        38.0          32.5
# 64            25.111111           38.0         2.0          59.5
# 32            23.800000           20.5        32.0          23.5
# 35            23.800000           20.5        32.0          23.5
# 23            24.125000           28.5        12.0          51.0
# 48            25.200000           41.0         4.0          43.0
# 10            23.823529           23.5        10.0          54.5
# 1             23.800000           20.5        25.5          23.5
# 73            24.727273           32.5         3.0          46.0
# 76            24.125000           28.5         1.0          51.0
# 41            23.176471           14.5         7.0          54.5
# 69            23.555556           18.0         9.0          42.0
# 67            20.000000           13.0        29.0           5.5
# 22            12.000000            7.0        16.0          32.5
# 17            15.000000           12.0        20.0          14.5
# 3              7.000000            3.0        25.5           5.5
# 29             4.000000            1.5        25.5           5.5
# 34             4.000000            1.5        25.5           5.5
# 83            10.000000            4.5        18.0          14.5
# 4             12.000000            7.0         6.0          32.5
#
#     ranking_total
# 68           99.7
# 39           96.5
# 85           94.1
# 5            89.1
# 77           88.8
# 74           85.1
# 44           83.6
# 25           82.6
# 15           80.7
# 24           80.2
# 13           79.0
# 43           77.6
# 20           76.5
# 27           74.7
# 9            73.9
# 47           71.8
# 28           71.7
# 65           70.7
# 79           68.8
# 2            68.7
# 61           66.4
# 54           63.4
# 11           62.5
# 75           60.4
# 8            59.7
# 37           59.0
# 31           59.0
# 21           57.1
# 71           56.8
# 14           56.6
# ..            ...
# 81           54.2
# 6            53.5
# 78           53.0
# 59           53.0
# 19           51.8
# 46           51.5
# 38           50.9
# 84           50.6
# 7            50.1
# 36           49.4
# 33           49.4
# 64           48.2
# 32           47.3
# 35           47.3
# 23           47.1
# 48           45.0
# 10           43.9
# 1            42.1
# 73           40.3
# 76           38.3
# 41           36.1
# 69           34.8
# 67           33.2
# 22           30.0
# 17           29.0
# 3            24.4
# 29           23.5
# 34           23.5
# 83           22.9
# 4            22.0
#
# [63 rows x 18 columns]

# %%
data_companies = data_companies.reset_index(drop=True)

# %%
data_companies.to_csv('./data_companies_select.csv')

# %%
res = requests.get("{}/json?location=49.285173,-123.095238&radius=1500&type=cafe&key={}&name=Starbucks".format(BASE_URL, KEY))

# %%
res = res.json()

# %%
coordinates_starbucks_latitude = []
coordinates_starbucks_longitude = []
for i in range(len(res)):
    coordinates_starbucks_latitude.append(res['results'][i]['geometry']['location']["lat"])
    coordinates_starbucks_longitude.append(res['results'][i]['geometry']['location']["lng"])
print(coordinates_starbucks_latitude, coordinates_starbucks_longitude)
# Out:
# [49.2856442, 49.2859207, 49.2844427] [-123.111855, -123.1151827, -123.108513]

# %%
dicc_starbucks = {'latitude_starbucks':coordinates_starbucks_latitude,
       'longitude_starbucks': coordinates_starbucks_longitude}
dataframe_starbucks = pd.DataFrame(dicc_starbucks)
display(dataframe_starbucks)
# Out:
#    latitude_starbucks  longitude_starbucks
# 0           49.285644          -123.111855
# 1           49.285921          -123.115183
# 2           49.284443          -123.108513

# %%
#Mapa con toda las compañías

# %%
map_companies = folium.Map(location=[51.510880, -0.141897], width=750, height=500, zoom_start=2)
for index, row in data_companies.iterrows():
    folium.CircleMarker([row['latitude'], row['longitude']],
                        radius=3,
                        popup="Country: {}. Money: {}. Name:{}".format(row['country'], row['total_money_raised'], row['name']),
                        fill_color="#F35C50", # divvy color
                       ).add_to(map_companies)

map_companies.save('map_companies.html')
map_companies
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#Mapa con las empresas del radio en la zona, escuelas cercanas (en rojo), Starbucks (verde) y la calle donde 
#sería interesante localizar la empresa

# %%
map_vancouver = folium.Map(location=[49.285173, -123.095238], width=750, height=500, zoom_start=15)
for index, row in data_companies.iterrows():
    folium.Marker([row['latitude'], row['longitude']],
                        radius=7,
                        popup="Name company: {}. Money: {}. Employees{}".format(row['name'], row['total_money_raised'], row['number_of_employees']),
                        icon=folium.Icon(color='red', icon='info-sign'),
                        fill_color="#F45649", 
                       ).add_to(map_vancouver)
for index, row in dataframe_schools.iterrows():
    folium.Marker([row['latitude_school'], row['longitude_school']],
                        radius=4,
                        popup="School: {}".format(row['name_school']),
                        icon=folium.Icon(icon='cloud'),
                        fill_color="#F35C50", # divvy color
                       ).add_to(map_vancouver)
for index, row in dataframe_starbucks.iterrows():
    folium.Marker([row['latitude_starbucks'], row['longitude_starbucks']],
                        radius=4,
                        icon=folium.Icon(color='darkgreen',icon='info-sign'),
                        fill_color="#F35C50", # divvy color
                       ).add_to(map_vancouver)
folium.Marker([49.282223,-123.109113],
                        radius=4,
                        icon=folium.Icon(color='pink',icon='info-sign'),
                        popup="Our company",
                        fill_color="#F35C50", # divvy color
                       ).add_to(map_vancouver)
map_vancouver.save('map_vancouver.html')
map_vancouver
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
